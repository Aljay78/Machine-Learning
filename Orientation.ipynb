# %% [markdown]
# <a href="https://colab.research.google.com/github/Aljay78/Machine-Learning/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Greetings="Great Work to be started"
print(Greetings)
# Out:
# Great Work to be started
