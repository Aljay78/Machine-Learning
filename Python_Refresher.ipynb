# %% [markdown]
# <a href="https://colab.research.google.com/github/Aljay78/Machine-Learning/blob/main/Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variable

# %%
#Create a labeled storage basket and put a number inside
tomato_price = 150
pepper_price = 80

#Pull the value out of the basket
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Change Tomato Price

# %%
tomato_price = 100
print(tomato_price)
# Out:
# 100

# %% [markdown]
# Variable (ML Anchor)

# %%
# --- THE CLUES (Features grouped as x) ---
rainful_mm = 45.2    # Clue 1
bags_available = 100 # Clue 2

# --- THE GOAL (Target labeled as y) ---
predicted_price = 3200 # What our AI calculates

print("Inputs (x):", rainful_mm, "mm rain,", bags_available, "bags.")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Inputs (x): 45.2 mm rain, 100 bags.
# Output (y): 3200 LRD.

# %% [markdown]
# Understanding Print

# %%
Liberia = 1847
print("Liberia")
print(Liberia)
# Out:
# Liberia
# 1847

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomato"
stall_is_open = True

print(type(quantity))      #
print(type(price))         #
print(type(item_name))     #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
